# %%
import pandas as pd

accomodations_clusters = pd.read_csv('/workspaces/SLO_LA_Olympics/clusters_central_location.csv')
venues = pd.read_csv('/workspaces/SLO_LA_Olympics/venues.csv')

# %%
venues = venues.dropna()

# %%
import folium

# Create a map centered at the average latitude and longitude
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=10)

# Add markers for each cluster
for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m)


# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e54ece363bdeae967e2a924d22d7c3b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e54ece363bdeae967e2a924d22d7c3b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e54ece363bdeae967e2a924d22d7c3b0 = L.map(
#                 &quot;map_e54ece363bdeae967e2a924d22d7c3b0&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cfcc1284b665cded083074eb3dd3811 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6cfcc1284b665cded083074eb3dd3811.addTo(map_e54ece363bdeae967e2a924d22d7c3b0);
#
#
#             var marker_113a3f73596e7efca3cebc323b1c748b = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_e54ece363bdeae967e2a924d22d7c3b0);
#
#
#         var popup_c7a0699843634cdc8fd8ce51468a4749 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5ece8ce60f6b671f51ba19ea93c51d0 = $(`&lt;div id=&quot;html_c5ece8ce60f6b671f51ba19ea93c51d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_c7a0699843634cdc8fd8ce51468a4749.setContent(html_c5ece8ce60f6b671f51ba19ea93c51d0);
#
#
#
#         marker_113a3f73596e7efca3cebc323b1c748b.bindPopup(popup_c7a0699843634cdc8fd8ce51468a4749)
#         ;
#
#
#
#
#             var marker_c86f719e62e740d2e872be0cd49e1da5 = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_e54ece363bdeae967e2a924d22d7c3b0);
#
#
#         var popup_f61518ec284d8f8ff937fa28301578d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7525933515a8faa93d41fd5eba4faad = $(`&lt;div id=&quot;html_d7525933515a8faa93d41fd5eba4faad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_f61518ec284d8f8ff937fa28301578d0.setContent(html_d7525933515a8faa93d41fd5eba4faad);
#
#
#
#         marker_c86f719e62e740d2e872be0cd49e1da5.bindPopup(popup_f61518ec284d8f8ff937fa28301578d0)
#         ;
#
#
#
#
#             var marker_53357937f164789688b9ee2a5c0724af = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_e54ece363bdeae967e2a924d22d7c3b0);
#
#
#         var popup_b52ec6a233e8c8a506932cf26858ef3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ce035f38c1ef53b4f88bc7adf6c6c69 = $(`&lt;div id=&quot;html_5ce035f38c1ef53b4f88bc7adf6c6c69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_b52ec6a233e8c8a506932cf26858ef3c.setContent(html_5ce035f38c1ef53b4f88bc7adf6c6c69);
#
#
#
#         marker_53357937f164789688b9ee2a5c0724af.bindPopup(popup_b52ec6a233e8c8a506932cf26858ef3c)
#         ;
#
#
#
#
#             var marker_9361585748edd935f934c8d06f10a650 = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_e54ece363bdeae967e2a924d22d7c3b0);
#
#
#         var popup_bb93f527fad779b65594a07488234095 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaef871cb6e820965feee468f33474c1 = $(`&lt;div id=&quot;html_aaef871cb6e820965feee468f33474c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_bb93f527fad779b65594a07488234095.setContent(html_aaef871cb6e820965feee468f33474c1);
#
#
#
#         marker_9361585748edd935f934c8d06f10a650.bindPopup(popup_bb93f527fad779b65594a07488234095)
#         ;
#
#
#
#
#             var marker_c9c15f54432785d9f0e001184c4914f7 = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_e54ece363bdeae967e2a924d22d7c3b0);
#
#
#         var popup_188a363f12c58077698f31de393f44f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ac9a2428f34718b1fd19f7d178afcd5 = $(`&lt;div id=&quot;html_7ac9a2428f34718b1fd19f7d178afcd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_188a363f12c58
