# %%
import pandas as pd

accomodations_clusters = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/clusters_central_location.csv')
venues = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/venues.csv')
time_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/matrixes/time_matrix.csv')
bus_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/matrixes/accomodations_to_venues.csv')
bus_terminals = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/bus_terminals.csv')
merged_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/matrixes/merged_matrix.csv')

# %%
venues = venues.dropna()

# %%
import folium

# Create a map centered at the average latitude and longitude
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=10)

# Add markers for each cluster
for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m)


# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m)
    
# Add markers for each bus terminal
for _, row in bus_terminals.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Terminal: {row['FACILITY']}",
        icon=folium.Icon(color='green')
    ).add_to(m)
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_862d3b26043e7895b85ce2a035056884 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_862d3b26043e7895b85ce2a035056884&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_862d3b26043e7895b85ce2a035056884 = L.map(
#                 &quot;map_862d3b26043e7895b85ce2a035056884&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c595e8f0c71e59d0aff6ad1311164ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c595e8f0c71e59d0aff6ad1311164ef.addTo(map_862d3b26043e7895b85ce2a035056884);
#
#
#             var marker_f49bde3e8f0084fd064c57eb6b8afe78 = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_862d3b26043e7895b85ce2a035056884);
#
#
#         var popup_19886f649f89fe13424feddef689907a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_031f335ee4811bbeced9dc493094fbf4 = $(`&lt;div id=&quot;html_031f335ee4811bbeced9dc493094fbf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_19886f649f89fe13424feddef689907a.setContent(html_031f335ee4811bbeced9dc493094fbf4);
#
#
#
#         marker_f49bde3e8f0084fd064c57eb6b8afe78.bindPopup(popup_19886f649f89fe13424feddef689907a)
#         ;
#
#
#
#
#             var marker_105926084560767b583a767e6741037b = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_862d3b26043e7895b85ce2a035056884);
#
#
#         var popup_d80bd26acb725c860278fa60da1fb85c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f8fb4181cc1ce4d9bc83c770a9a9117 = $(`&lt;div id=&quot;html_7f8fb4181cc1ce4d9bc83c770a9a9117&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_d80bd26acb725c860278fa60da1fb85c.setContent(html_7f8fb4181cc1ce4d9bc83c770a9a9117);
#
#
#
#         marker_105926084560767b583a767e6741037b.bindPopup(popup_d80bd26acb725c860278fa60da1fb85c)
#         ;
#
#
#
#
#             var marker_d87127d7876f2932739a2b22e958f815 = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_862d3b26043e7895b85ce2a035056884);
#
#
#         var popup_b7d96c5d5f88d251afba188666eec8da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23b91195baef099b1727737eed8dc5ff = $(`&lt;div id=&quot;html_23b91195baef099b1727737eed8dc5ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_b7d96c5d5f88d251afba188666eec8da.setContent(html_23b91195baef099b1727737eed8dc5ff);
#
#
#
#         marker_d87127d7876f2932739a2b22e958f815.bindPopup(popup_b7d96c5d5f88d251afba188666eec8da)
#         ;
#
#
#
#
#             var marker_6c6465a23242acc8d812dd04b6754249 = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_862d3b26043e7895b85ce2a035056884);
#
#
#         var popup_448147a2024b6cbe096fc700f8991488 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b67108de96ad8fa91f1d1b80e1382316 = $(`&lt;div id=&quot;html_b67108de96ad8fa91f1d1b80e1382316&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_448147a2024b6cbe096fc700f8991488.setContent(html_b67108de96ad8fa91f1d1b80e1382316);
#
#
#
#         marker_6c6465a23242acc8d812dd04b6754249.bindPopup(popup_448147a2024b6cbe096fc700f8991488)
#         ;
#
#
#
#
#             var marker_31e0d56c75703a339e192a10061302bc = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_862d3b26043e7895b85ce2a035056884);
#
#
#         var popup_9a166e564da19e3fba4136f3700717d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b20823229fd5298fafe6000fb40e470 = $(`&lt;div id=&quot;html_2b20823229fd5298fafe6000fb40e470&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_9a166e564da19

# %%
demand= accomodations_clusters['total_accommodates'].to_numpy()
demand
# Out:
# array([ 6969,  6395,  2801,  7026,  4909,  1545,  6342,  6399,  1171,
#         4117,  3110,  3088,  5080,  4779,  2666,  9095,  7555,  4679,
#         2111,  3376,  7538,  7068,  6853,  1576,  2974,  2110,  1319,
#        10383,  1268,   273,  8063,  8239,  3833,  6408,  7028,  2057,
#         4099,  2060,  2646,  2505,  6751,   934,  4119,  9229,   563,
#         7296,  2670,  2156,  2263,  1619, 12812])

# %%
from ortools.sat.python import cp_model

# Set the number of bus stops to locate
p = 15

# bus_matrix rows: accommodations; columns: candidate bus terminals
accom = list(bus_matrix.index)
bus_stops = list(bus_matrix.columns[1:])

model = cp_model.CpModel()

# Decision variables:
x = {j: model.NewBoolVar(f"x_{j}") for j in bus_stops}
y = {}
for idx, i in enumerate(accom):
    for j in bus_stops:
        y[(idx, j)] = model.NewBoolVar(f"y_{idx}_{j}")

# Constraint: each accommodation must be assigned to exactly one bus stop.
for idx, i in enumerate(accom):
    model.Add(sum(y[(idx, j)] for j in bus_stops) == 1)

# Constraint: assignment only possible if bus stop is selected.
for idx, i in enumerate(accom):
    for j in bus_stops:
        model.Add(y[(idx, j)] <= x[j])

# Constraint: exactly p bus stops are selected.
model.Add(sum(x[j] for j in bus_stops) == p)

# Objective: minimize total (demand-weighted) distance.
# We convert bus_matrix.loc[i, j] to an integer cost.
objective_terms = []
for idx, i in enumerate(accom):
    for j in bus_stops:
        # Multiply demand and the scaled distance.
        cost = int(round(bus_matrix.loc[i, j]))
        objective_terms.append(demand[idx] * cost * y[(idx, j)])
model.Minimize(sum(objective_terms))

# Solve the model.
solver = cp_model.CpSolver()
status = solver.Solve(model)

if status in [cp_model.OPTIMAL, cp_model.FEASIBLE]:
    selected = [j for j in bus_stops if solver.Value(x[j]) == 1]
    print("Selected bus stops:", selected)
else:
    print("No solution found.")
# Out:
# Selected bus stops: ['BD14', 'BD15', 'BD16', 'BT16', 'BT03', 'BT08', 'BT24', 'BL14', 'BD04', 'BT11', 'BT06', 'BT21', 'BL20', 'BT18', 'BL23']

# %%
#map only selected bus stops ['BD14', 'BD15', 'BT03', 'BL14', 'BT23', 'BT18', 'BL23', 'BL07', 'BT05']
# Add markers for each cluster
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m2 = folium.Map(location=map_center, zoom_start=10)

for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m2)
# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m2)

for _, row in bus_terminals[bus_terminals['id'].isin(selected)].iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Terminal: {row['FACILITY']}",
        icon=folium.Icon(color='lightgreen', icon='ok-sign')
    ).add_to(m2)
# Display the map with selected bus stops
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81b707e4552aabb66d761c172b2485a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81b707e4552aabb66d761c172b2485a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81b707e4552aabb66d761c172b2485a5 = L.map(
#                 &quot;map_81b707e4552aabb66d761c172b2485a5&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd2e64bcc4e00583b16bac8ca0727ce4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd2e64bcc4e00583b16bac8ca0727ce4.addTo(map_81b707e4552aabb66d761c172b2485a5);
#
#
#             var marker_3b2f63c3721b11d868e34d2b4f1595a7 = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_81b707e4552aabb66d761c172b2485a5);
#
#
#         var popup_e78f028dcbe170d52bd3a35ac3985282 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c9e9dba43f0a76bdb97485e7b44c4c9 = $(`&lt;div id=&quot;html_2c9e9dba43f0a76bdb97485e7b44c4c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_e78f028dcbe170d52bd3a35ac3985282.setContent(html_2c9e9dba43f0a76bdb97485e7b44c4c9);
#
#
#
#         marker_3b2f63c3721b11d868e34d2b4f1595a7.bindPopup(popup_e78f028dcbe170d52bd3a35ac3985282)
#         ;
#
#
#
#
#             var marker_659ff3c3f6e0a3c801bbd1db0d253049 = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_81b707e4552aabb66d761c172b2485a5);
#
#
#         var popup_237d30fa418d4450bec824b570e63828 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59bb687c15bced40d258bd6e2fbc4355 = $(`&lt;div id=&quot;html_59bb687c15bced40d258bd6e2fbc4355&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_237d30fa418d4450bec824b570e63828.setContent(html_59bb687c15bced40d258bd6e2fbc4355);
#
#
#
#         marker_659ff3c3f6e0a3c801bbd1db0d253049.bindPopup(popup_237d30fa418d4450bec824b570e63828)
#         ;
#
#
#
#
#             var marker_256b7cf4464b6acfe871f148d6718a44 = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_81b707e4552aabb66d761c172b2485a5);
#
#
#         var popup_bd8190762cedb0fc35801c40e9d4a16c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d832b601ebb59c8128097af4fffb688b = $(`&lt;div id=&quot;html_d832b601ebb59c8128097af4fffb688b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_bd8190762cedb0fc35801c40e9d4a16c.setContent(html_d832b601ebb59c8128097af4fffb688b);
#
#
#
#         marker_256b7cf4464b6acfe871f148d6718a44.bindPopup(popup_bd8190762cedb0fc35801c40e9d4a16c)
#         ;
#
#
#
#
#             var marker_2484b7cd7f64317161475d6c7747a82f = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_81b707e4552aabb66d761c172b2485a5);
#
#
#         var popup_a628a6b9e5d2faa61f8b57a23ef0a1e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2c023bba67be6a5bd7691603ce14899 = $(`&lt;div id=&quot;html_e2c023bba67be6a5bd7691603ce14899&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_a628a6b9e5d2faa61f8b57a23ef0a1e6.setContent(html_e2c023bba67be6a5bd7691603ce14899);
#
#
#
#         marker_2484b7cd7f64317161475d6c7747a82f.bindPopup(popup_a628a6b9e5d2faa61f8b57a23ef0a1e6)
#         ;
#
#
#
#
#             var marker_3598b7a2fdbabb6812e42c19706f35fb = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_81b707e4552aabb66d761c172b2485a5);
#
#
#         var popup_51900a67275da3a821aaa7a17908a09b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ee120f4280fb5ae483b1992bac87864 = $(`&lt;div id=&quot;html_6ee120f4280fb5ae483b1992bac87864&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_51900a67275da

# %%
merged_matrix
# Out:
#     Unnamed: 0      A1     A10     A11     A12     A13     A14     A15  \
# 0           A1     0.0  3304.0  3496.0  1727.0  1956.0  2020.0  2410.0
# 1          A10  3263.0     0.0  4901.0  2745.0  2974.0  3033.0  2460.0
# 2          A11  3459.0  4958.0     0.0  3305.0  3534.0  3598.0  4079.0
# 3          A12  1753.0  2784.0  3117.0     0.0   593.0  1014.0  1617.0
# 4          A13  1909.0  2939.0  3272.0   576.0     0.0   489.0  1654.0
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 149       BT24  2357.0  2960.0  3911.0  1473.0  1509.0  1455.0  1027.0
# 150       BT25  2234.0  2575.0  3788.0  1350.0  1386.0  1332.0   250.0
# 151       BT26  1594.0  2406.0  3326.0  1783.0  1938.0  2233.0  1496.0
# 152       BT27  1485.0  2420.0  3408.0  1424.0  1579.0  1874.0  1556.0
# 153       BT28  1745.0  2006.0  3477.0  1630.0  1785.0  2168.0  1208.0
#
#         A16     A17  ...    BT19    BT20    BT21    BT22    BT23    BT24  \
# 0    1512.0  3273.0  ...  1850.0  2149.0  1860.0  2759.0  2024.0  2357.0
# 1    2917.0  2778.0  ...  1696.0  1627.0  2491.0  2459.0  2890.0  2960.0
# 2    2432.0  4852.0  ...  3477.0  3757.0  3064.0  4313.0  3578.0  3911.0
# 3    1405.0  2390.0  ...  1556.0  1785.0  2037.0  1875.0  1140.0  1473.0
# 4    1561.0  2426.0  ...  1711.0  1940.0  2193.0  1911.0  1176.0  1509.0
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 149  2040.0  1565.0  ...  1847.0  1958.0  2368.0  1327.0   980.0     0.0
# 150  1918.0  1442.0  ...  1126.0  1238.0  1647.0   840.0   857.0   952.0
# 151  1365.0  2523.0  ...   933.0  1044.0  1418.0  1854.0  2018.0  2087.0
# 152  1447.0  2584.0  ...  1164.0  1311.0  1731.0  1914.0  1635.0  2047.0
# 153  1516.0  2236.0  ...   500.0   612.0   996.0  1566.0  1730.0  1799.0
#
#        BT25    BT26    BT27    BT28
# 0    2234.0  1594.0  1485.0  1745.0
# 1    2575.0  2406.0  2420.0  2006.0
# 2    3788.0  3326.0  3408.0  3477.0
# 3    1350.0  1783.0  1424.0  1630.0
# 4    1386.0  1938.0  1579.0  1785.0
# ..      ...     ...     ...     ...
# 149   934.0  1965.0  1990.0  1634.0
# 150     0.0  1244.0  1479.0   914.0
# 151  1345.0     0.0   357.0   707.0
# 152  1405.0   362.0     0.0   987.0
# 153  1058.0   715.0  1037.0     0.0
#
# [154 rows x 155 columns]

# %% [markdown]
# # VRP
