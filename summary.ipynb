# %%
import pandas as pd

accomodations_clusters = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/clusters_central_location.csv')
venues = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/venues.csv')
time_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/matrixes/time_matrix.csv')
bus_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/matrixes/accomodations_to_venues.csv')
bus_terminals = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/bus_terminals.csv')
merged_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/matrixes/merged_matrix.csv')

# %%
venues = venues.dropna()

# %%
import folium

# Create a map centered at the average latitude and longitude
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=10)

# Add markers for each cluster
for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m)


# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m)
    
# Add markers for each bus terminal
for _, row in bus_terminals.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Terminal: {row['FACILITY']}",
        icon=folium.Icon(color='green')
    ).add_to(m)
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_380ba9d5dcd8c84c9d3b994bb7c9b0d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_380ba9d5dcd8c84c9d3b994bb7c9b0d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_380ba9d5dcd8c84c9d3b994bb7c9b0d6 = L.map(
#                 &quot;map_380ba9d5dcd8c84c9d3b994bb7c9b0d6&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be0ab2a2db7255e33f614448b7e1225e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be0ab2a2db7255e33f614448b7e1225e.addTo(map_380ba9d5dcd8c84c9d3b994bb7c9b0d6);
#
#
#             var marker_edc51cc3b265f4eb3e7dd04937053c37 = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_380ba9d5dcd8c84c9d3b994bb7c9b0d6);
#
#
#         var popup_2aa9c648c32a4ce7bae3e487fd5b423e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56f1907e4c675b8d7e4c2b61c245262b = $(`&lt;div id=&quot;html_56f1907e4c675b8d7e4c2b61c245262b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_2aa9c648c32a4ce7bae3e487fd5b423e.setContent(html_56f1907e4c675b8d7e4c2b61c245262b);
#
#
#
#         marker_edc51cc3b265f4eb3e7dd04937053c37.bindPopup(popup_2aa9c648c32a4ce7bae3e487fd5b423e)
#         ;
#
#
#
#
#             var marker_670bd087548f5c08eb26afaa78b54741 = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_380ba9d5dcd8c84c9d3b994bb7c9b0d6);
#
#
#         var popup_bb1c067ef6394c276e6fe74a7b966fde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c82bd7949c98d7db334577a5fd6c7214 = $(`&lt;div id=&quot;html_c82bd7949c98d7db334577a5fd6c7214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_bb1c067ef6394c276e6fe74a7b966fde.setContent(html_c82bd7949c98d7db334577a5fd6c7214);
#
#
#
#         marker_670bd087548f5c08eb26afaa78b54741.bindPopup(popup_bb1c067ef6394c276e6fe74a7b966fde)
#         ;
#
#
#
#
#             var marker_3202b8e5fae19c18aedce3fc0a9bd945 = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_380ba9d5dcd8c84c9d3b994bb7c9b0d6);
#
#
#         var popup_b976e8e93b90648e28b58fa55a7ed3c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_528454f977440f1d5cb499b9ee813253 = $(`&lt;div id=&quot;html_528454f977440f1d5cb499b9ee813253&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_b976e8e93b90648e28b58fa55a7ed3c9.setContent(html_528454f977440f1d5cb499b9ee813253);
#
#
#
#         marker_3202b8e5fae19c18aedce3fc0a9bd945.bindPopup(popup_b976e8e93b90648e28b58fa55a7ed3c9)
#         ;
#
#
#
#
#             var marker_3a73ac7038c62e2b0b8ca74dd8bf118b = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_380ba9d5dcd8c84c9d3b994bb7c9b0d6);
#
#
#         var popup_bbdc6d561462c4aeff0ad4880654d9a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_442e170de9c1de5ef73d688e59c87bee = $(`&lt;div id=&quot;html_442e170de9c1de5ef73d688e59c87bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_bbdc6d561462c4aeff0ad4880654d9a2.setContent(html_442e170de9c1de5ef73d688e59c87bee);
#
#
#
#         marker_3a73ac7038c62e2b0b8ca74dd8bf118b.bindPopup(popup_bbdc6d561462c4aeff0ad4880654d9a2)
#         ;
#
#
#
#
#             var marker_33267bef2f0803c463cc0ea5e82d94c1 = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_380ba9d5dcd8c84c9d3b994bb7c9b0d6);
#
#
#         var popup_925f8cc040478942350c457b378191f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64bd32b158ddb1ceb157d39cd5046a89 = $(`&lt;div id=&quot;html_64bd32b158ddb1ceb157d39cd5046a89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_925f8cc040478

# %%
demand= accomodations_clusters['total_accommodates'].to_numpy()
demand
# Out:
# array([ 6969,  6395,  2801,  7026,  4909,  1545,  6342,  6399,  1171,
#         4117,  3110,  3088,  5080,  4779,  2666,  9095,  7555,  4679,
#         2111,  3376,  7538,  7068,  6853,  1576,  2974,  2110,  1319,
#        10383,  1268,   273,  8063,  8239,  3833,  6408,  7028,  2057,
#         4099,  2060,  2646,  2505,  6751,   934,  4119,  9229,   563,
#         7296,  2670,  2156,  2263,  1619, 12812])

# %%
from ortools.sat.python import cp_model

# Set the number of bus stops to locate
p = 15

# bus_matrix rows: accommodations; columns: candidate bus terminals
accom = list(bus_matrix.index)
bus_stops = list(bus_matrix.columns[1:])

model = cp_model.CpModel()

# Decision variables:
x = {j: model.NewBoolVar(f"x_{j}") for j in bus_stops}
y = {}
for idx, i in enumerate(accom):
    for j in bus_stops:
        y[(idx, j)] = model.NewBoolVar(f"y_{idx}_{j}")

# Constraint: each accommodation must be assigned to exactly one bus stop.
for idx, i in enumerate(accom):
    model.Add(sum(y[(idx, j)] for j in bus_stops) == 1)

# Constraint: assignment only possible if bus stop is selected.
for idx, i in enumerate(accom):
    for j in bus_stops:
        model.Add(y[(idx, j)] <= x[j])

# Constraint: exactly p bus stops are selected.
model.Add(sum(x[j] for j in bus_stops) == p)

# Objective: minimize total (demand-weighted) distance.
# We convert bus_matrix.loc[i, j] to an integer cost.
objective_terms = []
for idx, i in enumerate(accom):
    for j in bus_stops:
        # Multiply demand and the scaled distance.
        cost = int(round(bus_matrix.loc[i, j]))
        objective_terms.append(demand[idx] * cost * y[(idx, j)])
model.Minimize(sum(objective_terms))

# Solve the model.
solver = cp_model.CpSolver()
status = solver.Solve(model)

if status in [cp_model.OPTIMAL, cp_model.FEASIBLE]:
    selected = [j for j in bus_stops if solver.Value(x[j]) == 1]
    print("Selected bus stops:", selected)
else:
    print("No solution found.")
# Out:
# Selected bus stops: ['BD14', 'BD15', 'BD16', 'BT16', 'BT03', 'BT08', 'BT24', 'BL14', 'BD04', 'BT11', 'BT06', 'BT21', 'BL20', 'BT18', 'BL23']

# %%
#map only selected bus stops ['BD14', 'BD15', 'BT03', 'BL14', 'BT23', 'BT18', 'BL23', 'BL07', 'BT05']
# Add markers for each cluster
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m2 = folium.Map(location=map_center, zoom_start=10)

for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m2)
# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m2)

for _, row in bus_terminals[bus_terminals['id'].isin(selected)].iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Terminal: {row['FACILITY']}",
        icon=folium.Icon(color='lightgreen', icon='ok-sign')
    ).add_to(m2)
# Display the map with selected bus stops
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c42dc96e880763a3f254378a5374261 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c42dc96e880763a3f254378a5374261&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c42dc96e880763a3f254378a5374261 = L.map(
#                 &quot;map_3c42dc96e880763a3f254378a5374261&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8670307e16471b40feec8222169bff9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8670307e16471b40feec8222169bff9e.addTo(map_3c42dc96e880763a3f254378a5374261);
#
#
#             var marker_cdfbafbed3d7c158a4e109a68169d034 = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_3c42dc96e880763a3f254378a5374261);
#
#
#         var popup_7de0dc8929e752b58fd7bdf4946b604f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba7d51cc4c98f8f739ad5862fe2aba8e = $(`&lt;div id=&quot;html_ba7d51cc4c98f8f739ad5862fe2aba8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_7de0dc8929e752b58fd7bdf4946b604f.setContent(html_ba7d51cc4c98f8f739ad5862fe2aba8e);
#
#
#
#         marker_cdfbafbed3d7c158a4e109a68169d034.bindPopup(popup_7de0dc8929e752b58fd7bdf4946b604f)
#         ;
#
#
#
#
#             var marker_07ba03a036013b6678908e816cf0fd53 = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_3c42dc96e880763a3f254378a5374261);
#
#
#         var popup_e7c125dc5d789714e3e7255f6160360f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5992bf02d5d6ac88a404d92767c98ba = $(`&lt;div id=&quot;html_e5992bf02d5d6ac88a404d92767c98ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_e7c125dc5d789714e3e7255f6160360f.setContent(html_e5992bf02d5d6ac88a404d92767c98ba);
#
#
#
#         marker_07ba03a036013b6678908e816cf0fd53.bindPopup(popup_e7c125dc5d789714e3e7255f6160360f)
#         ;
#
#
#
#
#             var marker_9684c50e5c89cf7070277645f17ea798 = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_3c42dc96e880763a3f254378a5374261);
#
#
#         var popup_6c64de903b188e141dc9c359b0e39b24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c713a76ab78eb930c3b57fc0682981ef = $(`&lt;div id=&quot;html_c713a76ab78eb930c3b57fc0682981ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_6c64de903b188e141dc9c359b0e39b24.setContent(html_c713a76ab78eb930c3b57fc0682981ef);
#
#
#
#         marker_9684c50e5c89cf7070277645f17ea798.bindPopup(popup_6c64de903b188e141dc9c359b0e39b24)
#         ;
#
#
#
#
#             var marker_b68a0db2b4fdaf5549477e1d2fe3a867 = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_3c42dc96e880763a3f254378a5374261);
#
#
#         var popup_3fa633013fb40212d20d94a56e5cf388 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_615b5106dd83bbaa90365d5809202d09 = $(`&lt;div id=&quot;html_615b5106dd83bbaa90365d5809202d09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_3fa633013fb40212d20d94a56e5cf388.setContent(html_615b5106dd83bbaa90365d5809202d09);
#
#
#
#         marker_b68a0db2b4fdaf5549477e1d2fe3a867.bindPopup(popup_3fa633013fb40212d20d94a56e5cf388)
#         ;
#
#
#
#
#             var marker_996c13f95097155ba5fd06b64102e6df = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_3c42dc96e880763a3f254378a5374261);
#
#
#         var popup_87ed8e4e4f0c07c301a3359673c4ec7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4fa527b97945f01b1e0a838217784ff = $(`&lt;div id=&quot;html_e4fa527b97945f01b1e0a838217784ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_87ed8e4e4f0c0

# %%
merged_matrix
# Out:
#     Unnamed: 0      A1     A10     A11     A12     A13     A14     A15  \
# 0           A1     0.0  3304.0  3496.0  1727.0  1956.0  2020.0  2410.0
# 1          A10  3263.0     0.0  4901.0  2745.0  2974.0  3033.0  2460.0
# 2          A11  3459.0  4958.0     0.0  3305.0  3534.0  3598.0  4079.0
# 3          A12  1753.0  2784.0  3117.0     0.0   593.0  1014.0  1617.0
# 4          A13  1909.0  2939.0  3272.0   576.0     0.0   489.0  1654.0
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 149       BT24  2357.0  2960.0  3911.0  1473.0  1509.0  1455.0  1027.0
# 150       BT25  2234.0  2575.0  3788.0  1350.0  1386.0  1332.0   250.0
# 151       BT26  1594.0  2406.0  3326.0  1783.0  1938.0  2233.0  1496.0
# 152       BT27  1485.0  2420.0  3408.0  1424.0  1579.0  1874.0  1556.0
# 153       BT28  1745.0  2006.0  3477.0  1630.0  1785.0  2168.0  1208.0
#
#         A16     A17  ...    BT19    BT20    BT21    BT22    BT23    BT24  \
# 0    1512.0  3273.0  ...  1850.0  2149.0  1860.0  2759.0  2024.0  2357.0
# 1    2917.0  2778.0  ...  1696.0  1627.0  2491.0  2459.0  2890.0  2960.0
# 2    2432.0  4852.0  ...  3477.0  3757.0  3064.0  4313.0  3578.0  3911.0
# 3    1405.0  2390.0  ...  1556.0  1785.0  2037.0  1875.0  1140.0  1473.0
# 4    1561.0  2426.0  ...  1711.0  1940.0  2193.0  1911.0  1176.0  1509.0
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 149  2040.0  1565.0  ...  1847.0  1958.0  2368.0  1327.0   980.0     0.0
# 150  1918.0  1442.0  ...  1126.0  1238.0  1647.0   840.0   857.0   952.0
# 151  1365.0  2523.0  ...   933.0  1044.0  1418.0  1854.0  2018.0  2087.0
# 152  1447.0  2584.0  ...  1164.0  1311.0  1731.0  1914.0  1635.0  2047.0
# 153  1516.0  2236.0  ...   500.0   612.0   996.0  1566.0  1730.0  1799.0
#
#        BT25    BT26    BT27    BT28
# 0    2234.0  1594.0  1485.0  1745.0
# 1    2575.0  2406.0  2420.0  2006.0
# 2    3788.0  3326.0  3408.0  3477.0
# 3    1350.0  1783.0  1424.0  1630.0
# 4    1386.0  1938.0  1579.0  1785.0
# ..      ...     ...     ...     ...
# 149   934.0  1965.0  1990.0  1634.0
# 150     0.0  1244.0  1479.0   914.0
# 151  1345.0     0.0   357.0   707.0
# 152  1405.0   362.0     0.0   987.0
# 153  1058.0   715.0  1037.0     0.0
#
# [154 rows x 155 columns]

# %% [markdown]
# # VRP
