# %%
import pandas as pd
accomodations_clusters = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/clusters_central_location.csv')
venues = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/venues.csv')
bus_terminals = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/bus_terminals.csv')
df  = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/new_matrix.csv', index_col=0)                 # IDs in the index

# %%
df
# Out:
#               BD14    BD15    BD16    BT16    BT03    BT08    BT24    BL14  \
# Unnamed: 0
# BD14           0.0  1947.0  2868.0  1976.0  1858.0  1052.0  1691.0  1614.0
# BD15        1769.0     0.0  2951.0  1936.0  2129.0  1551.0  2180.0  2062.0
# BD16        2574.0  2932.0     0.0  2681.0  1420.0  2359.0  2987.0  2910.0
# BT16        1879.0  2037.0  2695.0     0.0  2130.0  1661.0  1979.0  1309.0
# BT03        1684.0  2044.0  1693.0  2049.0     0.0  1469.0  2097.0  2020.0
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# A47         2078.0  1621.0  2383.0  1070.0  1558.0  1772.0  2042.0  1360.0
# A48         1859.0  1334.0  2482.0  1250.0  1657.0  1553.0  2115.0  1432.0
# A49         1696.0  1592.0  2661.0   974.0  1836.0  1390.0  1669.0   987.0
# A50         1981.0  1788.0  2490.0   978.0  1666.0  1675.0  1945.0  1263.0
# A51         1607.0  1566.0  2726.0   871.0  1873.0  1301.0  1669.0   987.0
#
#               BD04    BT11  ...     A42     A43     A44     A45     A46  \
# Unnamed: 0                  ...
# BD14        2546.0  1472.0  ...  4028.0  1868.0  2199.0  2731.0  1740.0
# BD15        3054.0  1431.0  ...  4130.0  1827.0  1880.0  2813.0  1699.0
# BD16        3843.0  2627.0  ...  3226.0  2700.0  1826.0  1577.0  2519.0
# BT16        1598.0  1154.0  ...  4005.0   215.0  1603.0  2844.0   647.0
# BT03        2953.0  1737.0  ...  2850.0  2067.0  1163.0  1624.0  1694.0
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# A47         2299.0  1219.0  ...  3537.0  1007.0  1228.0  2259.0   687.0
# A48         2436.0  1002.0  ...  3637.0  1187.0  1328.0  2359.0   883.0
# A49         1991.0   836.0  ...  3816.0   874.0  1507.0  2538.0   592.0
# A50         2207.0  1122.0  ...  3644.0   915.0  1255.0  2367.0   595.0
# A51         1991.0   735.0  ...  3881.0   771.0  1513.0  2603.0   532.0
#
#                A47     A48     A49     A50     A51
# Unnamed: 0
# BD14        2078.0  1859.0  1696.0  1981.0  1607.0
# BD15        1621.0  1334.0  1592.0  1788.0  1566.0
# BD16        2383.0  2482.0  2661.0  2490.0  2726.0
# BT16        1070.0  1250.0   974.0   978.0   871.0
# BT03        1558.0  1657.0  1836.0  1666.0  1873.0
# ...            ...     ...     ...     ...     ...
# A47            0.0   722.0   795.0   564.0   858.0
# A48          705.0     0.0   458.0   969.0   831.0
# A49          719.0   458.0     0.0   889.0   396.0
# A50          560.0   916.0   840.0     0.0   766.0
# A51          917.0   871.0   428.0   833.0     0.0
#
# [80 rows x 80 columns]

# %%
import folium
metro = pd.read_csv('SLO_LA_Olympics/Metro.csv')
# Create a map centered around Los Angeles
m = folium.Map(location=[34.0522, -118.2437], zoom_start=12)
# Add markers for each metro station
for _, row in metro.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"ID: {row['stop_id']}<br>Stop: {row['stop_name']}",
        icon=folium.Icon(color='lightblue')
    ).add_to(m)
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c11abebcbcb36230e4665f386a67061 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c11abebcbcb36230e4665f386a67061&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c11abebcbcb36230e4665f386a67061 = L.map(
#                 &quot;map_9c11abebcbcb36230e4665f386a67061&quot;,
#                 {
#                     center: [34.0522, -118.2437],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79cb86fae5957534a1bf4d54f6927f69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_79cb86fae5957534a1bf4d54f6927f69.addTo(map_9c11abebcbcb36230e4665f386a67061);
#
#
#             var marker_2ca87e6b4901714dd36d4c403187499d = L.marker(
#                 [33.768071, -118.192921],
#                 {
# }
#             ).addTo(map_9c11abebcbcb36230e4665f386a67061);
#
#
#             var icon_53d1fc9af9ec5573628eb46ab6cbca8a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3b83d08aace49449210a94628508b22e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_590aac55f3418fdbf5c352b6c95d4e2a = $(`&lt;div id=&quot;html_590aac55f3418fdbf5c352b6c95d4e2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 80101&lt;br&gt;Stop: Downtown Long Beach Station&lt;/div&gt;`)[0];
#                 popup_3b83d08aace49449210a94628508b22e.setContent(html_590aac55f3418fdbf5c352b6c95d4e2a);
#
#
#
#         marker_2ca87e6b4901714dd36d4c403187499d.bindPopup(popup_3b83d08aace49449210a94628508b22e)
#         ;
#
#
#
#
#                 marker_2ca87e6b4901714dd36d4c403187499d.setIcon(icon_53d1fc9af9ec5573628eb46ab6cbca8a);
#
#
#             var marker_f926bc7cfcc0e7d58d22d65f861081f0 = L.marker(
#                 [33.772258, -118.1937],
#                 {
# }
#             ).addTo(map_9c11abebcbcb36230e4665f386a67061);
#
#
#             var icon_a246dc38f6947ceafcfa7d6d8b0ec899 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f9c5e1e52bb77db2e31260fc1b3ed868 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c8108fa43a461af934beac980dcde55 = $(`&lt;div id=&quot;html_2c8108fa43a461af934beac980dcde55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 80102&lt;br&gt;Stop: Pacific Ave Station&lt;/div&gt;`)[0];
#                 popup_f9c5e1e52bb77db2e31260fc1b3ed868.setContent(html_2c8108fa43a461af934beac980dcde55);
#
#
#
#         marker_f926bc7cfcc0e7d58d22d65f861081f0.bindPopup(popup_f9c5e1e52bb77db2e31260fc1b3ed868)
#         ;
#
#
#
#
#                 marker_f926bc7cfcc0e7d58d22d65f861081f0.setIcon(icon_a246dc38f6947ceafcfa7d6d8b0ec899);
#
#
#             var marker_ec4208a79aab85cc2234f123b5ce18aa = L.marker(
#                 [33.78183, -118.189384],
#                 {
# }
#             ).addTo(map_9c11abebcbcb36230e4665f386a67061);
#
#
#             var icon_7c8bd77b38e9766e6a51527ce9ae7d03 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c2467e118468e7dc7053310f5b13e7b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b9c2a82bcb84b98cb518277557b8ce6 = $(`&lt;div id=&quot;html_1b9c2a82bcb84b98cb518277557b8ce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 80105&lt;br&gt;Stop: Anaheim Street Station&lt;/div&gt;`)[0];
#                 popup_c2467e118468e7dc7053310f5b13e7b9.setContent(html_1b9c2a82bcb84b98cb518277557b8ce6);
#
#
#
#         marker_ec4208a79aab85cc2234f123b5ce18aa.bindPopup(popup_c2467e118468e7dc7053310f5b13e7b9)
#         ;
#
#
#
#
#                 marker_ec4208a79aab85cc2234f123b5ce18aa.setIcon(icon_7c8bd77b38e9766e6a51527ce9ae7d03);
#
#
#             var marker_64cb568d2ad8ac7d19f5ed60e37c4dfe = L.marker(
#                 [33.78909, -118.189382],
#                 {
# }
#             ).addTo(map_9c11ab
