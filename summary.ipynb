# %%
import pandas as pd

accomodations_clusters = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/clusters_central_location.csv')
venues = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/venues.csv')
time_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/time_matrix.csv')
bus_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/accomodations_to_venues.csv')
bus_terminals = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/bus_terminals.csv')

# %%
venues = venues.dropna()

# %%
import folium

# Create a map centered at the average latitude and longitude
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=10)

# Add markers for each cluster
for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m)


# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m)
    
# Add markers for each bus terminal
for _, row in bus_terminals.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Terminal: {row['FACILITY']}",
        icon=folium.Icon(color='green')
    ).add_to(m)
# Display the map
m
# Out:
# /Users/leonardogreco/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_220fc514cf2576169cce96f366055aed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_220fc514cf2576169cce96f366055aed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_220fc514cf2576169cce96f366055aed = L.map(
#                 &quot;map_220fc514cf2576169cce96f366055aed&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea9c1b9cd09599ba24b7e3fcdf751cdd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea9c1b9cd09599ba24b7e3fcdf751cdd.addTo(map_220fc514cf2576169cce96f366055aed);
#
#
#             var marker_b5c33e9b346859eabbf9352f2a2943f8 = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_220fc514cf2576169cce96f366055aed);
#
#
#         var popup_068a50948bc0de8f7f0cc272169e9c95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61c4e4f5a76638376a9d707a2880d03e = $(`&lt;div id=&quot;html_61c4e4f5a76638376a9d707a2880d03e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_068a50948bc0de8f7f0cc272169e9c95.setContent(html_61c4e4f5a76638376a9d707a2880d03e);
#
#
#
#         marker_b5c33e9b346859eabbf9352f2a2943f8.bindPopup(popup_068a50948bc0de8f7f0cc272169e9c95)
#         ;
#
#
#
#
#             var marker_2047032999bf5d9831afae09eedc0e1a = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_220fc514cf2576169cce96f366055aed);
#
#
#         var popup_ee060fa9efb219a6fd8326b0b4233256 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ea3d8a96d2b20ac587f6d55ab55880f = $(`&lt;div id=&quot;html_1ea3d8a96d2b20ac587f6d55ab55880f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_ee060fa9efb219a6fd8326b0b4233256.setContent(html_1ea3d8a96d2b20ac587f6d55ab55880f);
#
#
#
#         marker_2047032999bf5d9831afae09eedc0e1a.bindPopup(popup_ee060fa9efb219a6fd8326b0b4233256)
#         ;
#
#
#
#
#             var marker_f712ea4aef99bd97bdc91a1fb540b248 = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_220fc514cf2576169cce96f366055aed);
#
#
#         var popup_083a509dec05ef97e0672a70c5f610aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e56df9c379f43f01f24200c22cab2c94 = $(`&lt;div id=&quot;html_e56df9c379f43f01f24200c22cab2c94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_083a509dec05ef97e0672a70c5f610aa.setContent(html_e56df9c379f43f01f24200c22cab2c94);
#
#
#
#         marker_f712ea4aef99bd97bdc91a1fb540b248.bindPopup(popup_083a509dec05ef97e0672a70c5f610aa)
#         ;
#
#
#
#
#             var marker_9219982cffaec35cc2e9b67181119bb5 = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_220fc514cf2576169cce96f366055aed);
#
#
#         var popup_23e7709a97b0b3a8d4f61bd59c1349e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db416ea54cde5b45148019b184e29ee6 = $(`&lt;div id=&quot;html_db416ea54cde5b45148019b184e29ee6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_23e7709a97b0b3a8d4f61bd59c1349e4.setContent(html_db416ea54cde5b45148019b184e29ee6);
#
#
#
#         marker_9219982cffaec35cc2e9b67181119bb5.bindPopup(popup_23e7709a97b0b3a8d4f61bd59c1349e4)
#         ;
#
#
#
#
#             var marker_545c7018e637563a2648c084cbb9865b = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_220fc514cf2576169cce96f366055aed);
#
#
#         var popup_703624a26a058d95c0b0812fbb5a9bf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67fd2b753364ddf82efea5eb88b85c55 = $(`&lt;div id=&quot;html_67fd2b753364ddf82efea5eb88b85c55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_703624a26a058

# %%
time_matrix
# Out:
#    Unnamed: 0      V1   V2      V3      V4      V5      V6      V7      V8  \
# 0          V1     0.0  NaN  2540.0   497.0  1185.0  1961.0  2113.0   497.0
# 1          V2     NaN  0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 2          V3  2748.0  NaN     0.0  2572.0  2685.0  2454.0  1706.0  2572.0
# 3          V4   491.0  NaN  2421.0     0.0  1321.0  2097.0  2249.0     0.0
# 4          V5  1407.0  NaN  2851.0  1454.0     0.0  2310.0  2462.0  1454.0
# ..        ...     ...  ...     ...     ...     ...     ...     ...     ...
# 80        A47  1040.0  NaN  2722.0   836.0  1870.0  2582.0  2790.0   836.0
# 81        A48  1032.0  NaN  2902.0   806.0  1943.0  2719.0  2871.0   806.0
# 82        A49   667.0  NaN  2597.0   373.0  1497.0  2273.0  2426.0   373.0
# 83        A50   948.0  NaN  2629.0   744.0  1778.0  2490.0  2698.0   744.0
# 84        A51   668.0  NaN  2494.0   222.0  1497.0  2273.0  2426.0   222.0
#
#         V9  ...     A42     A43     A44     A45     A46     A47     A48  \
# 0   1840.0  ...  4051.0   814.0  1683.0  2703.0   714.0  1086.0  1064.0
# 1      NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   1999.0  ...  5643.0  2077.0  3248.0  4462.0  2390.0  2816.0  2940.0
# 3   1976.0  ...  3747.0   735.0  1379.0  2469.0   439.0   783.0   789.0
# 4   2192.0  ...  4182.0  1772.0  2320.0  2700.0  1672.0  2044.0  2052.0
# ..     ...  ...     ...     ...     ...     ...     ...     ...     ...
# 80  2465.0  ...  3537.0  1007.0  1228.0  2259.0   687.0     0.0   722.0
# 81  2598.0  ...  3637.0  1187.0  1328.0  2359.0   883.0   705.0     0.0
# 82  2153.0  ...  3816.0   874.0  1507.0  2538.0   592.0   719.0   458.0
# 83  2373.0  ...  3644.0   915.0  1255.0  2367.0   595.0   560.0   916.0
# 84  2153.0  ...  3881.0   771.0  1513.0  2603.0   532.0   917.0   871.0
#
#        A49     A50     A51
# 0    714.0  1003.0   563.0
# 1      NaN     NaN     NaN
# 2   2672.0  2733.0  2559.0
# 3    346.0   699.0   226.0
# 4   1672.0  1961.0  1521.0
# ..     ...     ...     ...
# 80   795.0   564.0   858.0
# 81   458.0   969.0   831.0
# 82     0.0   889.0   396.0
# 83   840.0     0.0   766.0
# 84   428.0   833.0     0.0
#
# [85 rows x 86 columns]

# %%
bus_matrix.head()
# Out:
#    id  BT25  BT07  BT13  BT10  BD01  BD02  BD05  BD06  BD09  ...  BL22  BL23  \
# 0  A1  2234  1766  1370  2384  2077  1938  1932  2472  1853  ...  2529  2558
# 1  A2  1750  1294  1042  1912  1632  1787  2402  1988  1382  ...  2580  2314
# 2  A3  1254   779   948  1397  1116  1271  2086  1594   866  ...  2265  1798
# 3  A4  1741  1267   650  1885  1604  1726  2050  2082  1354  ...  2647  2346
# 4  A5  2270  1640  2254  2414  1681  1453  2260  2348  1561  ...  2979   610
#
#    BT26  BL19  BT04  BT19  BL03  BL07  BT05  BT15
# 0  1594  1861  1854  1850  2308  1811  1372  2128
# 1  1486  1685  1472  1664  1818  1758   954  1717
# 2  1356  1170   957  1149  1302  1243   341  1201
# 3  1119  1700  1539  1638  1790  1599   814  1689
# 4  2077  1731  1724  1255  1826  1442  2052  1394
#
# [5 rows x 70 columns]

# %%
demand= accomodations_clusters['total_accommodates'].to_numpy()
demand
# Out:
# array([ 6969,  6395,  2801,  7026,  4909,  1545,  6342,  6399,  1171,
#         4117,  3110,  3088,  5080,  4779,  2666,  9095,  7555,  4679,
#         2111,  3376,  7538,  7068,  6853,  1576,  2974,  2110,  1319,
#        10383,  1268,   273,  8063,  8239,  3833,  6408,  7028,  2057,
#         4099,  2060,  2646,  2505,  6751,   934,  4119,  9229,   563,
#         7296,  2670,  2156,  2263,  1619, 12812])

# %%
from ortools.sat.python import cp_model

# Set the number of bus stops to locate
p = 15

# Assume bus_matrix rows: accommodations; columns: candidate bus stops
accom = list(bus_matrix.index)
bus_stops = list(bus_matrix.columns[1:])

scale = 1000  # scaling factor to convert float distances to integers

model = cp_model.CpModel()

# Decision variables:
x = {j: model.NewBoolVar(f"x_{j}") for j in bus_stops}
y = {}
for idx, i in enumerate(accom):
    for j in bus_stops:
        y[(idx, j)] = model.NewBoolVar(f"y_{idx}_{j}")

# Constraint: each accommodation must be assigned to exactly one bus stop.
for idx, i in enumerate(accom):
    model.Add(sum(y[(idx, j)] for j in bus_stops) == 1)

# Constraint: assignment only possible if bus stop is selected.
for idx, i in enumerate(accom):
    for j in bus_stops:
        model.Add(y[(idx, j)] <= x[j])

# Constraint: exactly p bus stops are selected.
model.Add(sum(x[j] for j in bus_stops) == p)

# Objective: minimize total (demand-weighted) distance.
# We convert bus_matrix.loc[i, j] to an integer cost.
objective_terms = []
for idx, i in enumerate(accom):
    for j in bus_stops:
        # Multiply demand and the scaled distance.
        cost = int(round(bus_matrix.loc[i, j] * scale))
        objective_terms.append(demand[idx] * cost * y[(idx, j)])
model.Minimize(sum(objective_terms))

# Solve the model.
solver = cp_model.CpSolver()
status = solver.Solve(model)

if status in [cp_model.OPTIMAL, cp_model.FEASIBLE]:
    selected = [j for j in bus_stops if solver.Value(x[j]) == 1]
    print("Selected bus stops:", selected)
else:
    print("No solution found.")
# Out:
# Selected bus stops: ['BD14', 'BD15', 'BD16', 'BT16', 'BT03', 'BT08', 'BT24', 'BL14', 'BD04', 'BT11', 'BT06', 'BT21', 'BL20', 'BT18', 'BL23']

# %%
#map only selected bus stops ['BD14', 'BD15', 'BT03', 'BL14', 'BT23', 'BT18', 'BL23', 'BL07', 'BT05']
# Add markers for each cluster
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m2 = folium.Map(location=map_center, zoom_start=10)

for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m2)
# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m2)

for _, row in bus_terminals[bus_terminals['id'].isin(selected)].iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Terminal: {row['FACILITY']}",
        icon=folium.Icon(color='lightgreen', icon='ok-sign')
    ).add_to(m2)
# Display the map with selected bus stops
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_975db6468bf2db71d42e2a2f4baa4304 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_975db6468bf2db71d42e2a2f4baa4304&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_975db6468bf2db71d42e2a2f4baa4304 = L.map(
#                 &quot;map_975db6468bf2db71d42e2a2f4baa4304&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36c20d4793a7af83938e4a8051e6f570 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36c20d4793a7af83938e4a8051e6f570.addTo(map_975db6468bf2db71d42e2a2f4baa4304);
#
#
#             var marker_a0f290485be4df665c7aec68d1664569 = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_975db6468bf2db71d42e2a2f4baa4304);
#
#
#         var popup_1039500d9a950460394774d9ca0371ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec5849d5ae8b9a09fcee2ed1b0e54dc1 = $(`&lt;div id=&quot;html_ec5849d5ae8b9a09fcee2ed1b0e54dc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_1039500d9a950460394774d9ca0371ce.setContent(html_ec5849d5ae8b9a09fcee2ed1b0e54dc1);
#
#
#
#         marker_a0f290485be4df665c7aec68d1664569.bindPopup(popup_1039500d9a950460394774d9ca0371ce)
#         ;
#
#
#
#
#             var marker_deb7feb9c3dcf475bec4fef020cdabb0 = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_975db6468bf2db71d42e2a2f4baa4304);
#
#
#         var popup_49860e4539c5bc288452674a7bf499df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fc42a78b7b1bebc7208123838949854 = $(`&lt;div id=&quot;html_8fc42a78b7b1bebc7208123838949854&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_49860e4539c5bc288452674a7bf499df.setContent(html_8fc42a78b7b1bebc7208123838949854);
#
#
#
#         marker_deb7feb9c3dcf475bec4fef020cdabb0.bindPopup(popup_49860e4539c5bc288452674a7bf499df)
#         ;
#
#
#
#
#             var marker_bc4cd9380c3292cf3b87e149b8aa22ce = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_975db6468bf2db71d42e2a2f4baa4304);
#
#
#         var popup_ecd4b40bff031b9e5fcebde80b3026e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b3d4393d5496fa8a59deec6cafa004c = $(`&lt;div id=&quot;html_7b3d4393d5496fa8a59deec6cafa004c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_ecd4b40bff031b9e5fcebde80b3026e4.setContent(html_7b3d4393d5496fa8a59deec6cafa004c);
#
#
#
#         marker_bc4cd9380c3292cf3b87e149b8aa22ce.bindPopup(popup_ecd4b40bff031b9e5fcebde80b3026e4)
#         ;
#
#
#
#
#             var marker_2b48289ff3590d480db8bf5d0be960df = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_975db6468bf2db71d42e2a2f4baa4304);
#
#
#         var popup_8f26c5ccb71877520e95d21dacef1001 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_302518e3da4705050e402318dccc29a6 = $(`&lt;div id=&quot;html_302518e3da4705050e402318dccc29a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_8f26c5ccb71877520e95d21dacef1001.setContent(html_302518e3da4705050e402318dccc29a6);
#
#
#
#         marker_2b48289ff3590d480db8bf5d0be960df.bindPopup(popup_8f26c5ccb71877520e95d21dacef1001)
#         ;
#
#
#
#
#             var marker_cdd42ba540c480b33a13e5dccd22396e = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_975db6468bf2db71d42e2a2f4baa4304);
#
#
#         var popup_b79a998a19334d78c0e93748880b1b35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3eb9ac6adaf40ce63b60ebe5d9ffdf0a = $(`&lt;div id=&quot;html_3eb9ac6adaf40ce63b60ebe5d9ffdf0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_b79a998a19334
