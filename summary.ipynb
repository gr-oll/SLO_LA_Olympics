# %%
import pandas as pd

accomodations_clusters = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/clusters_central_location.csv')
venues = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/venues.csv')
time_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/time_matrix.csv')
bus_terminals = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/bus_terminals.csv')

# %%
venues = venues.dropna()

# %%
import folium

# Create a map centered at the average latitude and longitude
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=10)

# Add markers for each cluster
for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m)


# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m)

for _, row in bus_terminals.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Terminal: {row['FACILITY']}",
        icon=folium.Icon(color='green')
    ).add_to(m)
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b14dcb92ea5fe22c7afb12dbdf6db013 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b14dcb92ea5fe22c7afb12dbdf6db013&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b14dcb92ea5fe22c7afb12dbdf6db013 = L.map(
#                 &quot;map_b14dcb92ea5fe22c7afb12dbdf6db013&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e48a8e52926c64241c515257180e4780 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e48a8e52926c64241c515257180e4780.addTo(map_b14dcb92ea5fe22c7afb12dbdf6db013);
#
#
#             var marker_bcb40eb6909f8bfeaca11db1e3fc17c9 = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_b14dcb92ea5fe22c7afb12dbdf6db013);
#
#
#         var popup_36307153fcd125ddf49e0d4fc80e3514 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43d61772034075516858461a3c8a8b4c = $(`&lt;div id=&quot;html_43d61772034075516858461a3c8a8b4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_36307153fcd125ddf49e0d4fc80e3514.setContent(html_43d61772034075516858461a3c8a8b4c);
#
#
#
#         marker_bcb40eb6909f8bfeaca11db1e3fc17c9.bindPopup(popup_36307153fcd125ddf49e0d4fc80e3514)
#         ;
#
#
#
#
#             var marker_196919ac6f1c34a236af892005eec0fe = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_b14dcb92ea5fe22c7afb12dbdf6db013);
#
#
#         var popup_b727cd11e093a09d2142824df715b0bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3dffe939e804894b88e8326750d69e7 = $(`&lt;div id=&quot;html_f3dffe939e804894b88e8326750d69e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_b727cd11e093a09d2142824df715b0bc.setContent(html_f3dffe939e804894b88e8326750d69e7);
#
#
#
#         marker_196919ac6f1c34a236af892005eec0fe.bindPopup(popup_b727cd11e093a09d2142824df715b0bc)
#         ;
#
#
#
#
#             var marker_8693d30e9d3e4923fdab5d88db34ce09 = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_b14dcb92ea5fe22c7afb12dbdf6db013);
#
#
#         var popup_df46249438350f37c4e12100fe4efd1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c45cb45328263f300a087706af12942 = $(`&lt;div id=&quot;html_8c45cb45328263f300a087706af12942&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_df46249438350f37c4e12100fe4efd1f.setContent(html_8c45cb45328263f300a087706af12942);
#
#
#
#         marker_8693d30e9d3e4923fdab5d88db34ce09.bindPopup(popup_df46249438350f37c4e12100fe4efd1f)
#         ;
#
#
#
#
#             var marker_af0fee23695a4c9b0059ab804b4ea2f2 = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_b14dcb92ea5fe22c7afb12dbdf6db013);
#
#
#         var popup_134d9eb083ef430c24a9c84258a9b945 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2621a528ed420de5117069e11e87bfd = $(`&lt;div id=&quot;html_e2621a528ed420de5117069e11e87bfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_134d9eb083ef430c24a9c84258a9b945.setContent(html_e2621a528ed420de5117069e11e87bfd);
#
#
#
#         marker_af0fee23695a4c9b0059ab804b4ea2f2.bindPopup(popup_134d9eb083ef430c24a9c84258a9b945)
#         ;
#
#
#
#
#             var marker_e08d827179d2a22eb367bf5a9cb64505 = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_b14dcb92ea5fe22c7afb12dbdf6db013);
#
#
#         var popup_de8c8412e833d82faca3508aee811cf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c54f0623a96ba45d0ea3f50553464f2 = $(`&lt;div id=&quot;html_6c54f0623a96ba45d0ea3f50553464f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_de8c8412e833d

# %%
time_matrix
# Out:
#    Unnamed: 0      V1   V2      V3      V4      V5      V6      V7      V8  \
# 0          V1     0.0  NaN  2540.0   497.0  1185.0  1961.0  2113.0   497.0
# 1          V2     NaN  0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 2          V3  2748.0  NaN     0.0  2572.0  2685.0  2454.0  1706.0  2572.0
# 3          V4   491.0  NaN  2421.0     0.0  1321.0  2097.0  2249.0     0.0
# 4          V5  1407.0  NaN  2851.0  1454.0     0.0  2310.0  2462.0  1454.0
# ..        ...     ...  ...     ...     ...     ...     ...     ...     ...
# 80        A47  1040.0  NaN  2722.0   836.0  1870.0  2582.0  2790.0   836.0
# 81        A48  1032.0  NaN  2902.0   806.0  1943.0  2719.0  2871.0   806.0
# 82        A49   667.0  NaN  2597.0   373.0  1497.0  2273.0  2426.0   373.0
# 83        A50   948.0  NaN  2629.0   744.0  1778.0  2490.0  2698.0   744.0
# 84        A51   668.0  NaN  2494.0   222.0  1497.0  2273.0  2426.0   222.0
#
#         V9  ...     A42     A43     A44     A45     A46     A47     A48  \
# 0   1840.0  ...  4051.0   814.0  1683.0  2703.0   714.0  1086.0  1064.0
# 1      NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   1999.0  ...  5643.0  2077.0  3248.0  4462.0  2390.0  2816.0  2940.0
# 3   1976.0  ...  3747.0   735.0  1379.0  2469.0   439.0   783.0   789.0
# 4   2192.0  ...  4182.0  1772.0  2320.0  2700.0  1672.0  2044.0  2052.0
# ..     ...  ...     ...     ...     ...     ...     ...     ...     ...
# 80  2465.0  ...  3537.0  1007.0  1228.0  2259.0   687.0     0.0   722.0
# 81  2598.0  ...  3637.0  1187.0  1328.0  2359.0   883.0   705.0     0.0
# 82  2153.0  ...  3816.0   874.0  1507.0  2538.0   592.0   719.0   458.0
# 83  2373.0  ...  3644.0   915.0  1255.0  2367.0   595.0   560.0   916.0
# 84  2153.0  ...  3881.0   771.0  1513.0  2603.0   532.0   917.0   871.0
#
#        A49     A50     A51
# 0    714.0  1003.0   563.0
# 1      NaN     NaN     NaN
# 2   2672.0  2733.0  2559.0
# 3    346.0   699.0   226.0
# 4   1672.0  1961.0  1521.0
# ..     ...     ...     ...
# 80   795.0   564.0   858.0
# 81   458.0   969.0   831.0
# 82     0.0   889.0   396.0
# 83   840.0     0.0   766.0
# 84   428.0   833.0     0.0
#
# [85 rows x 86 columns]
