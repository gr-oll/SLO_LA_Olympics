# %%
import pandas as pd

accomodations_clusters = pd.read_csv('/workspaces/SLO_LA_Olympics/clusters_central_location.csv')
venues = pd.read_csv('/workspaces/SLO_LA_Olympics/venues.csv')
time_matrix = pd.read_csv('/workspaces/SLO_LA_Olympics/time_matrix.csv')

# %%
venues = venues.dropna()

# %%
import folium

# Create a map centered at the average latitude and longitude
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=10)

# Add markers for each cluster
for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m)


# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5806946a38680f1f4e54f29682a334fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5806946a38680f1f4e54f29682a334fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5806946a38680f1f4e54f29682a334fb = L.map(
#                 &quot;map_5806946a38680f1f4e54f29682a334fb&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ead0cce6c8092eeb0a628a36aeb3ca5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ead0cce6c8092eeb0a628a36aeb3ca5e.addTo(map_5806946a38680f1f4e54f29682a334fb);
#
#
#             var marker_dfc4cf618b49a9e79d4b2c832e4c7927 = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_5806946a38680f1f4e54f29682a334fb);
#
#
#         var popup_1f5d80bd1366dc87c0d7c25b05652a24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fcb8b9c49cafda37953c821e7a80bc5 = $(`&lt;div id=&quot;html_2fcb8b9c49cafda37953c821e7a80bc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_1f5d80bd1366dc87c0d7c25b05652a24.setContent(html_2fcb8b9c49cafda37953c821e7a80bc5);
#
#
#
#         marker_dfc4cf618b49a9e79d4b2c832e4c7927.bindPopup(popup_1f5d80bd1366dc87c0d7c25b05652a24)
#         ;
#
#
#
#
#             var marker_d551c32473ad81429729155e7ccc70fc = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_5806946a38680f1f4e54f29682a334fb);
#
#
#         var popup_10bc2d92da2be766d86d80ce1d3e1d52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a1b0919a2ae921b314c904952fb22c7 = $(`&lt;div id=&quot;html_7a1b0919a2ae921b314c904952fb22c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_10bc2d92da2be766d86d80ce1d3e1d52.setContent(html_7a1b0919a2ae921b314c904952fb22c7);
#
#
#
#         marker_d551c32473ad81429729155e7ccc70fc.bindPopup(popup_10bc2d92da2be766d86d80ce1d3e1d52)
#         ;
#
#
#
#
#             var marker_b9007ec2261b09c755863cc0c693824d = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_5806946a38680f1f4e54f29682a334fb);
#
#
#         var popup_b3e8e92be6615c024bc63be1b78a2a47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac66833d84ebb185f32e0f0c762c267b = $(`&lt;div id=&quot;html_ac66833d84ebb185f32e0f0c762c267b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_b3e8e92be6615c024bc63be1b78a2a47.setContent(html_ac66833d84ebb185f32e0f0c762c267b);
#
#
#
#         marker_b9007ec2261b09c755863cc0c693824d.bindPopup(popup_b3e8e92be6615c024bc63be1b78a2a47)
#         ;
#
#
#
#
#             var marker_e148be5dc0626990a04d13c6d4c5c53e = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_5806946a38680f1f4e54f29682a334fb);
#
#
#         var popup_472c5b84ff089da333d8eea1046ccbe5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_659cccda74ad509876ee40241b83c2e7 = $(`&lt;div id=&quot;html_659cccda74ad509876ee40241b83c2e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_472c5b84ff089da333d8eea1046ccbe5.setContent(html_659cccda74ad509876ee40241b83c2e7);
#
#
#
#         marker_e148be5dc0626990a04d13c6d4c5c53e.bindPopup(popup_472c5b84ff089da333d8eea1046ccbe5)
#         ;
#
#
#
#
#             var marker_ae01fa94f25e593e329d38d29f7381e3 = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_5806946a38680f1f4e54f29682a334fb);
#
#
#         var popup_ab9c1a7c317c5ffb0e4b327619fc7079 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ba8e17588eda95cc933c3e80514eaaf = $(`&lt;div id=&quot;html_6ba8e17588eda95cc933c3e80514eaaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_ab9c1a7c317c5

# %%
time_matrix
# Out:
#    Unnamed: 0      V1   V2      V3      V4      V5      V6      V7      V8  \
# 0          V1     0.0  NaN  2540.0   497.0  1185.0  1961.0  2113.0   497.0
# 1          V2     NaN  0.0     NaN     NaN     NaN     NaN     NaN     NaN
# 2          V3  2748.0  NaN     0.0  2572.0  2685.0  2454.0  1706.0  2572.0
# 3          V4   491.0  NaN  2421.0     0.0  1321.0  2097.0  2249.0     0.0
# 4          V5  1407.0  NaN  2851.0  1454.0     0.0  2310.0  2462.0  1454.0
# ..        ...     ...  ...     ...     ...     ...     ...     ...     ...
# 80        A47  1040.0  NaN  2722.0   836.0  1870.0  2582.0  2790.0   836.0
# 81        A48  1032.0  NaN  2902.0   806.0  1943.0  2719.0  2871.0   806.0
# 82        A49   667.0  NaN  2597.0   373.0  1497.0  2273.0  2426.0   373.0
# 83        A50   948.0  NaN  2629.0   744.0  1778.0  2490.0  2698.0   744.0
# 84        A51   668.0  NaN  2494.0   222.0  1497.0  2273.0  2426.0   222.0
#
#         V9  ...     A42     A43     A44     A45     A46     A47     A48  \
# 0   1840.0  ...  4051.0   814.0  1683.0  2703.0   714.0  1086.0  1064.0
# 1      NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   1999.0  ...  5643.0  2077.0  3248.0  4462.0  2390.0  2816.0  2940.0
# 3   1976.0  ...  3747.0   735.0  1379.0  2469.0   439.0   783.0   789.0
# 4   2192.0  ...  4182.0  1772.0  2320.0  2700.0  1672.0  2044.0  2052.0
# ..     ...  ...     ...     ...     ...     ...     ...     ...     ...
# 80  2465.0  ...  3537.0  1007.0  1228.0  2259.0   687.0     0.0   722.0
# 81  2598.0  ...  3637.0  1187.0  1328.0  2359.0   883.0   705.0     0.0
# 82  2153.0  ...  3816.0   874.0  1507.0  2538.0   592.0   719.0   458.0
# 83  2373.0  ...  3644.0   915.0  1255.0  2367.0   595.0   560.0   916.0
# 84  2153.0  ...  3881.0   771.0  1513.0  2603.0   532.0   917.0   871.0
#
#        A49     A50     A51
# 0    714.0  1003.0   563.0
# 1      NaN     NaN     NaN
# 2   2672.0  2733.0  2559.0
# 3    346.0   699.0   226.0
# 4   1672.0  1961.0  1521.0
# ..     ...     ...     ...
# 80   795.0   564.0   858.0
# 81   458.0   969.0   831.0
# 82     0.0   889.0   396.0
# 83   840.0     0.0   766.0
# 84   428.0   833.0     0.0
#
# [85 rows x 86 columns]
