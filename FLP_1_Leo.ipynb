# %%
import pandas as pd

accomodations_clusters = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/datasets/clusters_central_location.csv')
venues = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/datasets/venues.csv')
updated_venues = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/datasets/updated_venues.csv')
time_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/matrixes/time_matrix.csv')
bus_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/matrixes/accomodations_to_venues.csv')
bus_terminals = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/datasets/bus_terminals.csv')
merged_matrix = pd.read_csv('https://raw.githubusercontent.com/gr-oll/SLO_LA_Olympics/main/matrixes/merged_matrix.csv')

# %%
venues = venues.dropna()

# %%
import folium

# Create a map centered at the average latitude and longitude
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=10)

# Add markers for each cluster
for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m)


# Add markers for each venue
for _, row in venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m)
    
# Add markers for each bus terminal
for _, row in bus_terminals.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Terminal: {row['FACILITY']}",
        icon=folium.Icon(color='green')
    ).add_to(m)
# Display the map
m
# Out:
# /Users/leonardogreco/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1a603eb2d4bbabbee6ed9bf1bfb4651 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1a603eb2d4bbabbee6ed9bf1bfb4651&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1a603eb2d4bbabbee6ed9bf1bfb4651 = L.map(
#                 &quot;map_f1a603eb2d4bbabbee6ed9bf1bfb4651&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4226154eedcb11cd8c706f027cdc527f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4226154eedcb11cd8c706f027cdc527f.addTo(map_f1a603eb2d4bbabbee6ed9bf1bfb4651);
#
#
#             var marker_1dfb5285c6f5c90373ad2014bec4c0ef = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_f1a603eb2d4bbabbee6ed9bf1bfb4651);
#
#
#         var popup_1617b834a1cb9e4f2ff84c8e77abf043 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9eaca66de004098e832965c77ee75617 = $(`&lt;div id=&quot;html_9eaca66de004098e832965c77ee75617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_1617b834a1cb9e4f2ff84c8e77abf043.setContent(html_9eaca66de004098e832965c77ee75617);
#
#
#
#         marker_1dfb5285c6f5c90373ad2014bec4c0ef.bindPopup(popup_1617b834a1cb9e4f2ff84c8e77abf043)
#         ;
#
#
#
#
#             var marker_ba0a7ba5a5c17a870f1e617d0129f1ee = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_f1a603eb2d4bbabbee6ed9bf1bfb4651);
#
#
#         var popup_a8f723fd5c28aa22ed41fb2cac5f7cdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5efb2a766b5e460a91b929405815bfe9 = $(`&lt;div id=&quot;html_5efb2a766b5e460a91b929405815bfe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_a8f723fd5c28aa22ed41fb2cac5f7cdc.setContent(html_5efb2a766b5e460a91b929405815bfe9);
#
#
#
#         marker_ba0a7ba5a5c17a870f1e617d0129f1ee.bindPopup(popup_a8f723fd5c28aa22ed41fb2cac5f7cdc)
#         ;
#
#
#
#
#             var marker_a605b47c44c48f0909d3008950e8b856 = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_f1a603eb2d4bbabbee6ed9bf1bfb4651);
#
#
#         var popup_ec201a775742931f932e709c13e545b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1159806e53c35d1030f790167f368125 = $(`&lt;div id=&quot;html_1159806e53c35d1030f790167f368125&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_ec201a775742931f932e709c13e545b4.setContent(html_1159806e53c35d1030f790167f368125);
#
#
#
#         marker_a605b47c44c48f0909d3008950e8b856.bindPopup(popup_ec201a775742931f932e709c13e545b4)
#         ;
#
#
#
#
#             var marker_3062605ae44d79eef51f842b0059c3fe = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_f1a603eb2d4bbabbee6ed9bf1bfb4651);
#
#
#         var popup_1af1a953c39399484ad6aefd3b0ccc9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15a85d79a4873123f9cb104ee4d784a1 = $(`&lt;div id=&quot;html_15a85d79a4873123f9cb104ee4d784a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_1af1a953c39399484ad6aefd3b0ccc9d.setContent(html_15a85d79a4873123f9cb104ee4d784a1);
#
#
#
#         marker_3062605ae44d79eef51f842b0059c3fe.bindPopup(popup_1af1a953c39399484ad6aefd3b0ccc9d)
#         ;
#
#
#
#
#             var marker_bff86037369e33b20fae825bd00e1853 = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_f1a603eb2d4bbabbee6ed9bf1bfb4651);
#
#
#         var popup_f5c61a9a73de9358ab3e75e25756f9b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a2ddbb09255be526443f078bc86c8da = $(`&lt;div id=&quot;html_7a2ddbb09255be526443f078bc86c8da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_f5c61a9a73de9

# %%
demand= accomodations_clusters['total_accommodates'].to_numpy()
demand
# Out:
# array([ 6969,  6395,  2801,  7026,  4909,  1545,  6342,  6399,  1171,
#         4117,  3110,  3088,  5080,  4779,  2666,  9095,  7555,  4679,
#         2111,  3376,  7538,  7068,  6853,  1576,  2974,  2110,  1319,
#        10383,  1268,   273,  8063,  8239,  3833,  6408,  7028,  2057,
#         4099,  2060,  2646,  2505,  6751,   934,  4119,  9229,   563,
#         7296,  2670,  2156,  2263,  1619, 12812])

# %%
from ortools.sat.python import cp_model

# Set the number of bus stops to locate
p = 15

# bus_matrix rows: accommodations; columns: candidate bus terminals
accom = list(bus_matrix.index)
bus_stops = list(bus_matrix.columns[1:])

model = cp_model.CpModel()

# Decision variables:
x = {j: model.NewBoolVar(f"x_{j}") for j in bus_stops}
y = {}
for idx, i in enumerate(accom):
    for j in bus_stops:
        y[(idx, j)] = model.NewBoolVar(f"y_{idx}_{j}")

# Constraint: each accommodation must be assigned to exactly one bus stop.
for idx, i in enumerate(accom):
    model.Add(sum(y[(idx, j)] for j in bus_stops) == 1)

# Constraint: assignment only possible if bus stop is selected.
for idx, i in enumerate(accom):
    for j in bus_stops:
        model.Add(y[(idx, j)] <= x[j])

# Constraint: exactly p bus stops are selected.
model.Add(sum(x[j] for j in bus_stops) == p)

# Objective: minimize total (demand-weighted) distance.
# We convert bus_matrix.loc[i, j] to an integer cost.
objective_terms = []
for idx, i in enumerate(accom):
    for j in bus_stops:
        # Multiply demand and the scaled distance.
        cost = int(round(bus_matrix.loc[i, j]))
        objective_terms.append(demand[idx] * cost * y[(idx, j)])
model.Minimize(sum(objective_terms))

# Solve the model.
solver = cp_model.CpSolver()
status = solver.Solve(model)

if status in [cp_model.OPTIMAL, cp_model.FEASIBLE]:
    selected = [j for j in bus_stops if solver.Value(x[j]) == 1]
    print("Selected bus stops:", selected)
else:
    print("No solution found.")
# Out:
# Selected bus stops: ['BD14', 'BD15', 'BD16', 'BT16', 'BT03', 'BT08', 'BT24', 'BL14', 'BD04', 'BT11', 'BT06', 'BT21', 'BL20', 'BT18', 'BL23']

# %%
#map only selected bus stops ['BD14', 'BD15', 'BT03', 'BL14', 'BT23', 'BT18', 'BL23', 'BL07', 'BT05']
# Add markers for each cluster
map_center = [accomodations_clusters['avg_latitude'].mean(), accomodations_clusters['avg_longitude'].mean()]
m2 = folium.Map(location=map_center, zoom_start=10)

for _, row in accomodations_clusters.iterrows():
    folium.Marker(
        location=[row['avg_latitude'], row['avg_longitude']],
        popup=f"ID: {row['id']}<br>Total Accommodates: {row['total_accommodates']}<br>Count: {row['count']}",
    ).add_to(m2)
# Add markers for each venue
for _, row in updated_venues.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Approx. Capacity: {row['Approx. Capacity']}<br>Venue: {row['Venue']}",
        icon=folium.Icon(color='purple')
    ).add_to(m2)

for _, row in bus_terminals[bus_terminals['id'].isin(selected)].iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id']}<br>Terminal: {row['FACILITY']}",
        icon=folium.Icon(color='lightgreen', icon='ok-sign')
    ).add_to(m2)
# Display the map with selected bus stops
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8de4446b9ae21a619445f7bfa558a9a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8de4446b9ae21a619445f7bfa558a9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8de4446b9ae21a619445f7bfa558a9a = L.map(
#                 &quot;map_e8de4446b9ae21a619445f7bfa558a9a&quot;,
#                 {
#                     center: [34.08839092519806, -118.30723028686349],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_addc195dd4c4cbd280ebcf7893a9ae90 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_addc195dd4c4cbd280ebcf7893a9ae90.addTo(map_e8de4446b9ae21a619445f7bfa558a9a);
#
#
#             var marker_0b40c1aaeafd07b5078ad9b0874cc164 = L.marker(
#                 [34.09555824883808, -118.38208159784384],
#                 {
# }
#             ).addTo(map_e8de4446b9ae21a619445f7bfa558a9a);
#
#
#         var popup_4a96b9cb3f02c1a840bbbff7daf8cea6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddb2ccf9b73b9fb6d7438aca06b05c2d = $(`&lt;div id=&quot;html_ddb2ccf9b73b9fb6d7438aca06b05c2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A1&lt;br&gt;Total Accommodates: 6969&lt;br&gt;Count: 1211&lt;/div&gt;`)[0];
#                 popup_4a96b9cb3f02c1a840bbbff7daf8cea6.setContent(html_ddb2ccf9b73b9fb6d7438aca06b05c2d);
#
#
#
#         marker_0b40c1aaeafd07b5078ad9b0874cc164.bindPopup(popup_4a96b9cb3f02c1a840bbbff7daf8cea6)
#         ;
#
#
#
#
#             var marker_3b775f15c217bb3beb29cf82f2e66c60 = L.marker(
#                 [34.0670000688382, -118.3927374830445],
#                 {
# }
#             ).addTo(map_e8de4446b9ae21a619445f7bfa558a9a);
#
#
#         var popup_05c8fdaec64d1bd42b37a1025945b2e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bcac9e8dab9bf12e03610704a6047e1 = $(`&lt;div id=&quot;html_1bcac9e8dab9bf12e03610704a6047e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A2&lt;br&gt;Total Accommodates: 6395&lt;br&gt;Count: 1091&lt;/div&gt;`)[0];
#                 popup_05c8fdaec64d1bd42b37a1025945b2e9.setContent(html_1bcac9e8dab9bf12e03610704a6047e1);
#
#
#
#         marker_3b775f15c217bb3beb29cf82f2e66c60.bindPopup(popup_05c8fdaec64d1bd42b37a1025945b2e9)
#         ;
#
#
#
#
#             var marker_65fb5e58936c27c1ce67ae8763c76e2b = L.marker(
#                 [34.04496699215145, -118.37122591266498],
#                 {
# }
#             ).addTo(map_e8de4446b9ae21a619445f7bfa558a9a);
#
#
#         var popup_45d7147fa8e701278a20e909fcf8e37f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d14126eadabdbca3e08969fa907e0de6 = $(`&lt;div id=&quot;html_d14126eadabdbca3e08969fa907e0de6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A3&lt;br&gt;Total Accommodates: 2801&lt;br&gt;Count: 693&lt;/div&gt;`)[0];
#                 popup_45d7147fa8e701278a20e909fcf8e37f.setContent(html_d14126eadabdbca3e08969fa907e0de6);
#
#
#
#         marker_65fb5e58936c27c1ce67ae8763c76e2b.bindPopup(popup_45d7147fa8e701278a20e909fcf8e37f)
#         ;
#
#
#
#
#             var marker_cabbc5c2565980ffe54853c35b08c347 = L.marker(
#                 [34.071703547218675, -118.36439019538808],
#                 {
# }
#             ).addTo(map_e8de4446b9ae21a619445f7bfa558a9a);
#
#
#         var popup_e8594df2cb83ab7cd92fb84e68479b64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63e47fa42e3cf96a74efe34c10ff11e9 = $(`&lt;div id=&quot;html_63e47fa42e3cf96a74efe34c10ff11e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A4&lt;br&gt;Total Accommodates: 7026&lt;br&gt;Count: 1218&lt;/div&gt;`)[0];
#                 popup_e8594df2cb83ab7cd92fb84e68479b64.setContent(html_63e47fa42e3cf96a74efe34c10ff11e9);
#
#
#
#         marker_cabbc5c2565980ffe54853c35b08c347.bindPopup(popup_e8594df2cb83ab7cd92fb84e68479b64)
#         ;
#
#
#
#
#             var marker_0a32ca85f44ed76698e2dcb647229554 = L.marker(
#                 [34.10683624942996, -118.0305058513991],
#                 {
# }
#             ).addTo(map_e8de4446b9ae21a619445f7bfa558a9a);
#
#
#         var popup_d2e5cfc234b05d3c5c4b111673dd0b03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c06897a476e946ba690ef58e851df54e = $(`&lt;div id=&quot;html_c06897a476e946ba690ef58e851df54e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: A5&lt;br&gt;Total Accommodates: 4909&lt;br&gt;Count: 1283&lt;/div&gt;`)[0];
#                 popup_d2e5cfc234b05

# %%
merged_matrix
# Out:
#     Unnamed: 0      A1     A10     A11     A12     A13     A14     A15  \
# 0           A1     0.0  3304.0  3496.0  1727.0  1956.0  2020.0  2410.0
# 1          A10  3263.0     0.0  4901.0  2745.0  2974.0  3033.0  2460.0
# 2          A11  3459.0  4958.0     0.0  3305.0  3534.0  3598.0  4079.0
# 3          A12  1753.0  2784.0  3117.0     0.0   593.0  1014.0  1617.0
# 4          A13  1909.0  2939.0  3272.0   576.0     0.0   489.0  1654.0
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 149       BT24  2357.0  2960.0  3911.0  1473.0  1509.0  1455.0  1027.0
# 150       BT25  2234.0  2575.0  3788.0  1350.0  1386.0  1332.0   250.0
# 151       BT26  1594.0  2406.0  3326.0  1783.0  1938.0  2233.0  1496.0
# 152       BT27  1485.0  2420.0  3408.0  1424.0  1579.0  1874.0  1556.0
# 153       BT28  1745.0  2006.0  3477.0  1630.0  1785.0  2168.0  1208.0
#
#         A16     A17  ...    BT19    BT20    BT21    BT22    BT23    BT24  \
# 0    1512.0  3273.0  ...  1850.0  2149.0  1860.0  2759.0  2024.0  2357.0
# 1    2917.0  2778.0  ...  1696.0  1627.0  2491.0  2459.0  2890.0  2960.0
# 2    2432.0  4852.0  ...  3477.0  3757.0  3064.0  4313.0  3578.0  3911.0
# 3    1405.0  2390.0  ...  1556.0  1785.0  2037.0  1875.0  1140.0  1473.0
# 4    1561.0  2426.0  ...  1711.0  1940.0  2193.0  1911.0  1176.0  1509.0
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 149  2040.0  1565.0  ...  1847.0  1958.0  2368.0  1327.0   980.0     0.0
# 150  1918.0  1442.0  ...  1126.0  1238.0  1647.0   840.0   857.0   952.0
# 151  1365.0  2523.0  ...   933.0  1044.0  1418.0  1854.0  2018.0  2087.0
# 152  1447.0  2584.0  ...  1164.0  1311.0  1731.0  1914.0  1635.0  2047.0
# 153  1516.0  2236.0  ...   500.0   612.0   996.0  1566.0  1730.0  1799.0
#
#        BT25    BT26    BT27    BT28
# 0    2234.0  1594.0  1485.0  1745.0
# 1    2575.0  2406.0  2420.0  2006.0
# 2    3788.0  3326.0  3408.0  3477.0
# 3    1350.0  1783.0  1424.0  1630.0
# 4    1386.0  1938.0  1579.0  1785.0
# ..      ...     ...     ...     ...
# 149   934.0  1965.0  1990.0  1634.0
# 150     0.0  1244.0  1479.0   914.0
# 151  1345.0     0.0   357.0   707.0
# 152  1405.0   362.0     0.0   987.0
# 153  1058.0   715.0  1037.0     0.0
#
# [154 rows x 155 columns]

# %% [markdown]
# # VRP
